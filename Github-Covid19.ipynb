# %%
#Task 1.1: Importing modules

import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt 
print('modules are imported')
# Out:
# modules are imported

# %%
#Task 1.2: Loading the dataset

dataset_url = r"C:\Users\admin\Documents\Covid19(Python).txt"
df = pd.read_csv(dataset_url)

# %%
#Task 1.2: Let's check the dataframe

df.head()
# Out:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-23  Afghanistan          0          0       0
# 2  2020-01-24  Afghanistan          0          0       0
# 3  2020-01-25  Afghanistan          0          0       0
# 4  2020-01-26  Afghanistan          0          0       0

# %%
df.tail()
# Out:
#               Date   Country  Confirmed  Recovered  Deaths
# 161563  2022-04-12  Zimbabwe     247094          0    5460
# 161564  2022-04-13  Zimbabwe     247160          0    5460
# 161565  2022-04-14  Zimbabwe     247208          0    5462
# 161566  2022-04-15  Zimbabwe     247237          0    5462
# 161567  2022-04-16  Zimbabwe     247237          0    5462

# %%
#Task 1.3: Let's check the shape of the dataframe

df.shape
# Out:
# (161568, 5)

# %%
#Task 2.1: Let's get all of the rows in which the Confirmed column is more than zero

df = df[df.Confirmed > 0]

# %%
df.head()
# Out:
#           Date      Country  Confirmed  Recovered  Deaths
# 33  2020-02-24  Afghanistan          5          0       0
# 34  2020-02-25  Afghanistan          5          0       0
# 35  2020-02-26  Afghanistan          5          0       0
# 36  2020-02-27  Afghanistan          5          0       0
# 37  2020-02-28  Afghanistan          5          0       0

# %%
#Task 2.2: Let's see global spread of COVID-19

fig = px.choropleth(df, locations="Country", locationmode="country names", color="Confirmed"
                   ,animation_frame="Date")
fig.update_layout(title_text = "Global Spread of COVID-19")
fig.show()

# %%
#Task 2.2: Let's see global deaths of COVID-19

fig = px.choropleth(df, locations="Country", locationmode="country names", color="Deaths"
                   ,animation_frame="Date")
fig.update_layout(title_text = "Global Deaths of COVID-19")
fig.show()

# %%
#Task 3.1: Let's see data related to India

df_india = df[df.Country == "India"]
df_india.head()
# Out:
#              Date Country  Confirmed  Recovered  Deaths
# 65280  2020-01-22   India          0          0       0
# 65281  2020-01-23   India          0          0       0
# 65282  2020-01-24   India          0          0       0
# 65283  2020-01-25   India          0          0       0
# 65284  2020-01-26   India          0          0       0

# %%
#Task 3.2: Let's select the columns that we need

df_india = df_india[["Date", "Confirmed"]]
df_india.head()
# Out:
#              Date  Confirmed
# 65280  2020-01-22          0
# 65281  2020-01-23          0
# 65282  2020-01-24          0
# 65283  2020-01-25          0
# 65284  2020-01-26          0

# %%
#Task 3.3: Let's calculate the first derivation of confirmed column

df_india["Infection Rate"] = df_india["Confirmed"].diff()
df_india.head()
# Out:
#              Date  Confirmed  Infection Rate
# 65280  2020-01-22          0             NaN
# 65281  2020-01-23          0             0.0
# 65282  2020-01-24          0             0.0
# 65283  2020-01-25          0             0.0
# 65284  2020-01-26          0             0.0

# %%
#Task 3.4: Let's visualize that relationship

px.line(df_india, x = "Date", y = ["Confirmed", "Infection Rate"] )

# %%
#Task 3.5: Let's calculate the maximum infection rate or the maximum number off new infected cases in one day in India

df_india["Infection Rate"].max()
# Out:
# 414188.0

# %%
#Task 3.2: Let's calculate maximum infection rate for all of the countries

df.head()
# Out:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-23  Afghanistan          0          0       0
# 2  2020-01-24  Afghanistan          0          0       0
# 3  2020-01-25  Afghanistan          0          0       0
# 4  2020-01-26  Afghanistan          0          0       0

# %%
countries = list(df["Country"].unique())
max_infection_rates = []
for c in countries:
    MIR = df[df.Country == c].Confirmed.diff().max()
    max_infection_rates.append(MIR)

# %%
#Task 3.3: Let's create a new Dataframe

df_MIR = pd.DataFrame()
df_MIR["Country"] = countries
df_MIR["Max Infection Rate"] = max_infection_rates
df_MIR.head()
# Out:
#        Country  Max Infection Rate
# 0  Afghanistan              3243.0
# 1      Albania              4789.0
# 2      Algeria              2521.0
# 3      Andorra              2313.0
# 4       Angola              5035.0

# %%
#Task 3.4: Let's plot the barchart: maximum infection rate of each country

px.bar(df_MIR, x="Country", y="Max Infection Rate", color="Country", title="Global Maximum Infection Rate", log_y=True)

# %%
#COVID-19 pandemic lockdown in India
#Task 4.1: Lets make variables with the lockdown start date and a month later

india_lockdown_start_date = '2020-03-16'
india_lockdown_a_month_later = '2020-04-20'

# %%
#Task 4.2: Let's get data related to India and check the dataframe

df_india = df[df.Country == "India"]
df_india.head()
# Out:
#              Date Country  Confirmed  Recovered  Deaths
# 65280  2020-01-22   India          0          0       0
# 65281  2020-01-23   India          0          0       0
# 65282  2020-01-24   India          0          0       0
# 65283  2020-01-25   India          0          0       0
# 65284  2020-01-26   India          0          0       0

# %%
#Task 4.3: Let's calculate the infection rate in India

df_india["Infection Rate"] = df_india.Confirmed.diff()
df_india.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5900\336767993.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              Date Country  Confirmed  Recovered  Deaths  Infection Rate
# 65280  2020-01-22   India          0          0       0             NaN
# 65281  2020-01-23   India          0          0       0             0.0
# 65282  2020-01-24   India          0          0       0             0.0
# 65283  2020-01-25   India          0          0       0             0.0
# 65284  2020-01-26   India          0          0       0             0.0

# %%
#Task 4.4: Let's do the visualization

fig = px.line(df_india, x="Date", y="Infection Rate", title = "Before and After Lockdown in India")
fig.add_shape(
    dict(
    type="line",
    x0=india_lockdown_start_date,
    y0=0,
    x1=india_lockdown_start_date,
    y1=df_india["Infection Rate"].max(),
    line=dict(color="red", width=2)
    )
)

fig.add_annotation(
    dict(
    x = india_lockdown_start_date,
    y = df_india["Infection Rate"].max(),
    text = "Starting date of the lockdown"
    )
)

fig.add_shape(
    dict(
    type="line",
    x0=india_lockdown_a_month_later,
    y0=0,
    x1=india_lockdown_a_month_later,
    y1=df_india["Infection Rate"].max(),
    line=dict(color="black", width=2)
    )
)

fig.add_annotation(
    dict(
    x = india_lockdown_a_month_later,
    y = df_india["Infection Rate"].max(),
    text = "A month later"
    )
)
# Out:
# <div>                            <div id="ad36b7fd-1b82-45e0-bddc-995c917ab512" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad36b7fd-1b82-45e0-bddc-995c917ab512")) {                    Plotly.newPlot(                        "ad36b7fd-1b82-45e0-bddc-995c917ab512",                        [{"hovertemplate":"Date=%{x}<br>Infection Rate=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-01-22","2020-01-23","2020-01-24","2020-01-25","2020-01-26","2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09
# ...

# %%
#5. Let's see how national lockdown impacts COVID-19 active cases in India
#5.1: Let's check the Dataframe before

df_india.head()
# Out:
#              Date Country  Confirmed  Recovered  Deaths  Infection Rate
# 65280  2020-01-22   India          0          0       0             NaN
# 65281  2020-01-23   India          0          0       0             0.0
# 65282  2020-01-24   India          0          0       0             0.0
# 65283  2020-01-25   India          0          0       0             0.0
# 65284  2020-01-26   India          0          0       0             0.0

# %%
#5.2: Let's calculate the deaths rate

df_india["Deaths Rate"] = df_india.Deaths.diff()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5900\2885199442.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Task 5.3: Let's check the dataframe after

df_india.head()
# Out:
#              Date Country  Confirmed  Recovered  Deaths  Infection Rate  \
# 65280  2020-01-22   India          0          0       0             NaN
# 65281  2020-01-23   India          0          0       0             0.0
# 65282  2020-01-24   India          0          0       0             0.0
# 65283  2020-01-25   India          0          0       0             0.0
# 65284  2020-01-26   India          0          0       0             0.0
#
#        Deaths Rate
# 65280          NaN
# 65281          0.0
# 65282          0.0
# 65283          0.0
# 65284          0.0

# %%
#Task 5.4: Let's plot a line chart to compare COVID-19 national lockdown impacts on spread of the virus and number of active cases

fig = px.line(df_india,x="Date",y=["Infection Rate", "Deaths Rate"])
fig.show()

# %%
#Task 5.6: Let's plot the line chart again

fig = px.line(df_india, x="Date", y=["Infection Rate", "Deaths Rate"])

fig.add_shape(
    dict(
    type="line",
    x0=india_lockdown_start_date,
    y0=0,
    x1=india_lockdown_start_date,
    y1=df_india["Infection Rate"].max(),
    line=dict(color="black", width=3)
    )
)

fig.add_annotation(
    dict(
    x = india_lockdown_start_date,
    y = df_india["Infection Rate"].max(),
    text = "Starting date of the lockdown"
    )
)

fig.add_shape(
    dict(
    type="line",
    x0=india_lockdown_a_month_later,
    y0=0,
    x1=india_lockdown_a_month_later,
    y1=df_india["Infection Rate"].max(),
    line=dict(color="black", width=3)
    )
)

fig.add_annotation(
    dict(
    x = india_lockdown_a_month_later,
    y = df_india["Infection Rate"].max(),
    text = "A month later"
    )
)

fig.show()
# Out:
# <div>                            <div id="2be39ccf-e5cc-455a-ba25-fafb2168a69d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2be39ccf-e5cc-455a-ba25-fafb2168a69d")) {                    Plotly.newPlot(                        "2be39ccf-e5cc-455a-ba25-fafb2168a69d",                        [{"hovertemplate":"variable=Infection Rate<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Infection Rate","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Infection Rate","showlegend":true,"x":["2020-01-22","2020-01-23","2020-01-24","2020-01-25","2020-01-26","2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-0
# ...
